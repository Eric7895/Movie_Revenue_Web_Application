# %% [markdown]
# ### This file focuses on finding a balance between movie records and number of attributes
#  - The goal is to merge the offical IMDB data with budget and gross income information to ensure minimum modeling
#  - End result - A csv file named 'balanced.csv' that has only 9371 records and around 26 attributes (Can be lesser, some variables might be unrelevant)
#  - The only downfall of this approach is that we are missing the actor attributes

# %%
import pandas as pd
import numpy as np

# %%
imdb = 'data/imdb_data.csv'
path1 = 'raw data/final_dataset.csv'
path2 = 'raw data/IMDB-Movie-Data.csv'
path3 = 'raw data/Movie_data.csv'
path4 = 'raw data/movies.csv'
path5 = 'raw data/imdb_movies.csv'

reading_list = [path1, path2, path3, path4, path5]

# %%
def initial_inspection(file):
    df = pd.read_csv(file)
    return df

# %% [markdown]
# #### Initial Inspection

# %%
index = 1
for i in reading_list:
    df = initial_inspection(i)
    print(f'path {index}: has shape {df.shape} and columns {df.columns}')
    print('------------------------------------------------------------------------------------------------------------')
    index += 1
# Out:
# path 1: has shape (7118, 8) and columns Index(['name', 'genre', 'score', 'director', 'actor_2_name', 'actor_1_name',
#        'gross', 'budget'],
#       dtype='object')
# ------------------------------------------------------------------------------------------------------------
# path 2: has shape (1000, 12) and columns Index(['Rank', 'Title', 'Genre', 'Description', 'Director', 'Actors', 'Year',
#        'Runtime (Minutes)', 'Rating', 'Votes', 'Revenue (Millions)',
#        'Metascore'],
#       dtype='object')
# ------------------------------------------------------------------------------------------------------------
# path 3: has shape (17034, 22) and columns Index(['id', 'title', 'genres', 'original_language', 'overview', 'popularity',
#        'production_companies', 'release_date', 'budget', 'revenue', 'runtime',
#        'status', 'tagline', 'vote_average', 'vote_count', 'credits',
#        'keywords', 'poster_path', 'backdrop_path', 'recommendations',
#        'trailer_views', 'trailer_likes'],
#       dtype='object')
# ------------------------------------------------------------------------------------------------------------
# path 4: has shape (7668, 15) and columns Index(['name', 'rating', 'genre', 'year', 'released', 'score', 'votes',
#        'director', 'writer', 'star', 'country', 'budget', 'gross', 'company',
#        'runtime'],
#       dtype='object')
# ------------------------------------------------------------------------------------------------------------
# path 5: has shape (10178, 12) and columns Index(['names', 'date_x', 'score', 'genre', 'overview', 'crew', 'orig_title',
#        'status', 'orig_lang', 'budget_x', 'revenue', 'country'],
#       dtype='object')
# ------------------------------------------------------------------------------------------------------------

# %%
imdb_df = pd.read_csv(imdb)
print(imdb_df.shape)
print(imdb_df.columns)
# Out:
# (324324, 11)
# Index(['Unnamed: 0', 'titleId', 'primaryTitle', 'originalTitle', 'titleType',
#        'startYear', 'genres', 'directors', 'writers', 'averageRating',
#        'numVotes'],
#       dtype='object')
# C:\Users\wue77\AppData\Local\Temp\ipykernel_92420\2555966851.py:1: DtypeWarning: Columns (5) have mixed types. Specify dtype option on import or set low_memory=False.
#   imdb_df = pd.read_csv(imdb)

# %%
selected_df = pd.read_csv(path3)
print(selected_df.shape)
print(selected_df.columns)
# Out:
# (17034, 22)
# Index(['id', 'title', 'genres', 'original_language', 'overview', 'popularity',
#        'production_companies', 'release_date', 'budget', 'revenue', 'runtime',
#        'status', 'tagline', 'vote_average', 'vote_count', 'credits',
#        'keywords', 'poster_path', 'backdrop_path', 'recommendations',
#        'trailer_views', 'trailer_likes'],
#       dtype='object')

# %% [markdown]
# #### Merge and fact checking

# %%
imdb_df.rename(columns={'genres': 'Genre'}, inplace=True)

# %%
imdb_df.iloc[0]
# Out:
# Unnamed: 0                     0
# titleId                tt0000009
# primaryTitle          Miss Jerry
# originalTitle         Miss Jerry
# titleType                  movie
# startYear                   1894
# Genre                    Romance
# directors        Alexander Black
# writers          Alexander Black
# averageRating                5.4
# numVotes                   218.0
# Name: 0, dtype: object

# %%
year_released = []

for i in range(selected_df.shape[0]):
    try:
        year_released.append(selected_df.iloc[i,7][:4])
    except Exception as e:
        print(f'Unexpected error at index {i}: {e}')
        year_released.append(None)
# Out:
# Unexpected error at index 6412: 'float' object is not subscriptable
# Unexpected error at index 6591: 'float' object is not subscriptable
# Unexpected error at index 9601: 'float' object is not subscriptable
# Unexpected error at index 10807: 'float' object is not subscriptable
# Unexpected error at index 11433: 'float' object is not subscriptable
# Unexpected error at index 11555: 'float' object is not subscriptable
# Unexpected error at index 11664: 'float' object is not subscriptable
# Unexpected error at index 11818: 'float' object is not subscriptable
# Unexpected error at index 12007: 'float' object is not subscriptable
# Unexpected error at index 12487: 'float' object is not subscriptable
# Unexpected error at index 12500: 'float' object is not subscriptable
# Unexpected error at index 12793: 'float' object is not subscriptable
# Unexpected error at index 13267: 'float' object is not subscriptable
# Unexpected error at index 13306: 'float' object is not subscriptable
# Unexpected error at index 13361: 'float' object is not subscriptable
# Unexpected error at index 13385: 'float' object is not subscriptable
# Unexpected error at index 13465: 'float' object is not subscriptable
# Unexpected error at index 13685: 'float' object is not subscriptable
# Unexpected error at index 13740: 'float' object is not subscriptable
# Unexpected error at index 13760: 'float' object is not subscriptable
# Unexpected error at index 13830: 'float' object is not subscriptable
# Unexpected error at index 13923: 'float' object is not subscriptable
# Unexpected error at index 13924: 'float' object is not subscriptable
# Unexpected error at index 13925: 'float' object is not subscriptable
# Unexpected error at index 13926: 'float' object is not subscriptable
# Unexpected error at index 13971: 'float' object is not subscriptable
# Unexpected error at index 14263: 'float' object is not subscriptable
# Unexpected error at index 14266: 'float' object is not subscriptable
# Unexpected error at index 14296: 'float' object is not subscriptable
# Unexpected error at index 14368: 'float' object is not subscriptable
# Unexpected error at index 14371: 'float' object is not subscriptable
# Unexpected error at index 14487: 'float' object is not subscriptable
# Unexpected error at index 14538: 'float' object is not subscriptable
# Unexpected error at index 14625: 'float' object is not subscriptable
# Unexpected error at index 14662: 'float' object is not subscriptable
# Unexpected error at index 14687: 'float' object is not subscriptable
# Unexpected error at index 14697: 'float' object is not subscriptable
# Unexpected error at index 14699: 'float' object is not subscriptable
# Unexpected error at index 14774: 'float' object is not subscriptable
# Unexpected error at index 14776: 'float' object is not subscriptable
# Unexpected error at index 14782: 'float' object is not subscriptable
# Unexpected error at index 14790: 'float' object is not subscriptable
# Unexpected error at index 14795: 'float' object is not subscriptable
# Unexpected error at index 14798: 'float' object is not subscriptable
# Unexpected error at index 14807: 'float' object is not subscriptable
# Unexpected error at index 14813: 'float' object is not subscriptable
# Unexpected error at index 14828: 'float' object is not subscriptable
# Unexpected error at index 14831: 'float' object is not subscriptable
# Unexpected error at index 14835: 'float' object is not subscriptable
# Unexpected error at index 14836: 'float' object is not subscriptable
# Unexpected error at index 14864: 'float' object is not subscriptable
# Unexpected error at index 14865: 'float' object is not subscriptable
# Unexpected error at index 14868: 'float' object is not subscriptable
# Unexpected error at index 14869: 'float' object is not subscriptable
# Unexpected error at index 14870: 'float' object is not subscriptable
# Unexpected error at index 14871: 'float' object is not subscriptable
# Unexpected error at index 14899: 'float' object is not subscriptable
# Unexpected error at index 14902: 'float' object is not subscriptable
# Unexpected error at index 14995: 'float' object is not subscriptable
# Unexpected error at index 15021: 'float' object is not subscriptable
# Unexpected error at index 15133: 'float' object is not subscriptable
# Unexpected error at index 15151: 'float' object is not subscriptable
# Unexpected error at index 15152: 'float' object is not subscriptable
# Unexpected error at index 15169: 'float' object is not subscriptable
# Unexpected error at index 15227: 'float' object is not subscriptable
# Unexpected error at index 15246: 'float' object is not subscriptable
# Unexpected error at index 15265: 'float' object is not subscriptable
# Unexpected error at index 15269: 'float' object is not subscriptable
# Unexpected error at index 15270: 'float' object is not subscriptable
# Unexpected error at index 15322: 'float' object is not subscriptable
# Unexpected error at index 15332: 'float' object is not subscriptable
# Unexpected error at index 15346: 'float' object is not subscriptable
# Unexpected error at index 15349: 'float' object is not subscriptable
# Unexpected error at index 15353: 'float' object is not subscriptable
# Unexpected error at index 15356: 'float' object is not subscriptable
# Unexpected error at index 15362: 'float' object is not subscriptable
# Unexpected error at index 15366: 'float' object is not subscriptable
# Unexpected error at index 15369: 'float' object is not subscriptable
# Unexpected error at index 15381: 'float' object is not subscriptable
# Unexpected error at index 15382: 'float' object is not subscriptable
# Unexpected error at index 15383: 'float' object is not subscriptable
# Unexpected error at index 15386: 'float' object is not subscriptable
# Unexpected error at index 15390: 'float' object is not subscriptable
# Unexpected error at index 15392: 'float' object is not subscriptable
# Unexpected error at index 15395: 'float' object is not subscriptable
# Unexpected error at index 15396: 'float' object is not subscriptable
# Unexpected error at index 15397: 'float' object is not subscriptable
# Unexpected error at index 15401: 'float' object is not subscriptable
# Unexpected error at index 15403: 'float' object is not subscriptable
# Unexpected error at index 15404: 'float' object is not subscriptable
# Unexpected error at index 15411: 'float' object is not subscriptable
# Unexpected error at index 15414: 'float' object is not subscriptable
# Unexpected error at index 15416: 'float' object is not subscriptable
# Unexpected error at index 15419: 'float' object is not subscriptable
# Unexpected error at index 15422: 'float' object is not subscriptable
# Unexpected error at index 15429: 'float' object is not subscriptable
# Unexpected error at index 15433: 'float' object is not subscriptable
# Unexpected error at index 15436: 'float' object is not subscriptable
# Unexpected error at index 15437: 'float' object is not subscriptable
# Unexpected error at index 15439: 'float' object is not subscriptable
# Unexpected error at index 15444: 'float' object is not subscriptable
# Unexpected error at index 15445: 'float' object is not subscriptable
# Unexpected error at index 15446: 'float' object is not subscriptable
# Unexpected error at index 15450: 'float' object is not subscriptable
# Unexpected error at index 15452: 'float' object is not subscriptable
# Unexpected error at index 15453: 'float' object is not subscriptable
# Unexpected error at index 15461: 'float' object is not subscriptable
# Unexpected error at index 15462: 'float' object is not subscriptable
# Unexpected error at index 15465: 'float' object is not subscriptable
# Unexpected error at index 15466: 'float' object is not subscriptable
# Unexpected error at index 15467: 'float' object is not subscriptable
# Unexpected error at index 15471: 'float' object is not subscriptable
# Unexpected error at index 15472: 'float' object is not subscriptable
# Unexpected error at index 15475: 'float' object is not subscriptable
# Unexpected error at index 15476: 'float' object is not subscriptable
# Unexpected error at index 15478: 'float' object is not subscriptable
# Unexpected error at index 15484: 'float' object is not subscriptable
# Unexpected error at index 15485: 'float' object is not subscriptable
# Unexpected error at index 15490: 'float' object is not subscriptable
# Unexpected error at index 15497: 'float' object is not subscriptable
# Unexpected error at index 15503: 'float' object is not subscriptable
# Unexpected error at index 15519: 'float' object is not subscriptable
# Unexpected error at index 15520: 'float' object is not subscriptable
# Unexpected error at index 15528: 'float' object is not subscriptable
# Unexpected error at index 15532: 'float' object is not subscriptable
# Unexpected error at index 15535: 'float' object is not subscriptable
# Unexpected error at index 15541: 'float' object is not subscriptable
# Unexpected error at index 15543: 'float' object is not subscriptable
# Unexpected error at index 15544: 'float' object is not subscriptable
# Unexpected error at index 15549: 'float' object is not subscriptable
# Unexpected error at index 15550: 'float' object is not subscriptable
# Unexpected error at index 15551: 'float' object is not subscriptable
# Unexpected error at index 15554: 'float' object is not subscriptable
# Unexpected error at index 15556: 'float' object is not subscriptable
# Unexpected error at index 15565: 'float' object is not subscriptable
# Unexpected error at index 15571: 'float' object is not subscriptable
# Unexpected error at index 15575: 'float' object is not subscriptable
# Unexpected error at index 15577: 'float' object is not subscriptable
# Unexpected error at index 15580: 'float' object is not subscriptable
# Unexpected error at index 15581: 'float' object is not subscriptable
# Unexpected error at index 15583: 'float' object is not subscriptable
# Unexpected error at index 15587: 'float' object is not subscriptable
# Unexpected error at index 15590: 'float' object is not subscriptable
# Unexpected error at index 15592: 'float' object is not subscriptable
# Unexpected error at index 15600: 'float' object is not subscriptable
# Unexpected error at index 15602: 'float' object is not subscriptable
# Unexpected error at index 15604: 'float' object is not subscriptable
# Unexpected error at index 15605: 'float' object is not subscriptable
# Unexpected error at index 15607: 'float' object is not subscriptable
# Unexpected error at index 15608: 'float' object is not subscriptable
# Unexpected error at index 15612: 'float' object is not subscriptable
# Unexpected error at index 15616: 'float' object is not subscriptable
# Unexpected error at index 15618: 'float' object is not subscriptable
# Unexpected error at index 15619: 'float' object is not subscriptable
# Unexpected error at index 15621: 'float' object is not subscriptable
# Unexpected error at index 15623: 'float' object is not subscriptable
# Unexpected error at index 15624: 'float' object is not subscriptable
# Unexpected error at index 15625: 'float' object is not subscriptable
# Unexpected error at index 15627: 'float' object is not subscriptable
# Unexpected error at index 15632: 'float' object is not subscriptable
# Unexpected error at index 15635: 'float' object is not subscriptable
# Unexpected error at index 15637: 'float' object is not subscriptable
# Unexpected error at index 15639: 'float' object is not subscriptable
# Unexpected error at index 15643: 'float' object is not subscriptable
# Unexpected error at index 15644: 'float' object is not subscriptable
# Unexpected error at index 15646: 'float' object is not subscriptable
# Unexpected error at index 15648: 'float' object is not subscriptable
# Unexpected error at index 15651: 'float' object is not subscriptable
# Unexpected error at index 15652: 'float' object is not subscriptable
# Unexpected error at index 15655: 'float' object is not subscriptable
# Unexpected error at index 15658: 'float' object is not subscriptable
# Unexpected error at index 15664: 'float' object is not subscriptable
# Unexpected error at index 15669: 'float' object is not subscriptable
# Unexpected error at index 15671: 'float' object is not subscriptable
# Unexpected error at index 15673: 'float' object is not subscriptable
# Unexpected error at index 15674: 'float' object is not subscriptable
# Unexpected error at index 15677: 'float' object is not subscriptable
# Unexpected error at index 15679: 'float' object is not subscriptable
# Unexpected error at index 15680: 'float' object is not subscriptable
# Unexpected error at index 15681: 'float' object is not subscriptable
# Unexpected error at index 15684: 'float' object is not subscriptable
# Unexpected error at index 15688: 'float' object is not subscriptable
# Unexpected error at index 15689: 'float' object is not subscriptable
# Unexpected error at index 15690: 'float' object is not subscriptable
# Unexpected error at index 15691: 'float' object is not subscriptable
# Unexpected error at index 15692: 'float' object is not subscriptable
# Unexpected error at index 15694: 'float' object is not subscriptable
# Unexpected error at index 15696: 'float' object is not subscriptable
# Unexpected error at index 15704: 'float' object is not subscriptable
# Unexpected error at index 15711: 'float' object is not subscriptable
# Unexpected error at index 15714: 'float' object is not subscriptable
# Unexpected error at index 15715: 'float' object is not subscriptable
# Unexpected error at index 15730: 'float' object is not subscriptable
# Unexpected error at index 15732: 'float' object is not subscriptable
# Unexpected error at index 15736: 'float' object is not subscriptable
# Unexpected error at index 15737: 'float' object is not subscriptable
# Unexpected error at index 15738: 'float' object is not subscriptable
# Unexpected error at index 15750: 'float' object is not subscriptable
# Unexpected error at index 15751: 'float' object is not subscriptable
# Unexpected error at index 15752: 'float' object is not subscriptable
# Unexpected error at index 15754: 'float' object is not subscriptable
# Unexpected error at index 15755: 'float' object is not subscriptable
# Unexpected error at index 15759: 'float' object is not subscriptable
# Unexpected error at index 15761: 'float' object is not subscriptable
# Unexpected error at index 15762: 'float' object is not subscriptable
# Unexpected error at index 15766: 'float' object is not subscriptable
# Unexpected error at index 15767: 'float' object is not subscriptable
# Unexpected error at index 15768: 'float' object is not subscriptable
# Unexpected error at index 15769: 'float' object is not subscriptable
# Unexpected error at index 15773: 'float' object is not subscriptable
# Unexpected error at index 15774: 'float' object is not subscriptable
# Unexpected error at index 15775: 'float' object is not subscriptable
# Unexpected error at index 15779: 'float' object is not subscriptable
# Unexpected error at index 15785: 'float' object is not subscriptable
# Unexpected error at index 15791: 'float' object is not subscriptable
# Unexpected error at index 15800: 'float' object is not subscriptable
# Unexpected error at index 15802: 'float' object is not subscriptable
# Unexpected error at index 15803: 'float' object is not subscriptable
# Unexpected error at index 15805: 'float' object is not subscriptable
# Unexpected error at index 15806: 'float' object is not subscriptable
# Unexpected error at index 15810: 'float' object is not subscriptable
# Unexpected error at index 15811: 'float' object is not subscriptable
# Unexpected error at index 15814: 'float' object is not subscriptable
# Unexpected error at index 15815: 'float' object is not subscriptable
# Unexpected error at index 15816: 'float' object is not subscriptable
# Unexpected error at index 15817: 'float' object is not subscriptable
# Unexpected error at index 15821: 'float' object is not subscriptable
# Unexpected error at index 15824: 'float' object is not subscriptable
# Unexpected error at index 15825: 'float' object is not subscriptable
# Unexpected error at index 15826: 'float' object is not subscriptable
# Unexpected error at index 15828: 'float' object is not subscriptable
# Unexpected error at index 15833: 'float' object is not subscriptable
# Unexpected error at index 15835: 'float' object is not subscriptable
# Unexpected error at index 15838: 'float' object is not subscriptable
# Unexpected error at index 15840: 'float' object is not subscriptable
# Unexpected error at index 15848: 'float' object is not subscriptable
# Unexpected error at index 15851: 'float' object is not subscriptable
# Unexpected error at index 15854: 'float' object is not subscriptable
# Unexpected error at index 15857: 'float' object is not subscriptable
# Unexpected error at index 15858: 'float' object is not subscriptable
# Unexpected error at index 15862: 'float' object is not subscriptable
# Unexpected error at index 15863: 'float' object is not subscriptable
# Unexpected error at index 15868: 'float' object is not subscriptable
# Unexpected error at index 15870: 'float' object is not subscriptable
# Unexpected error at index 15873: 'float' object is not subscriptable
# Unexpected error at index 15874: 'float' object is not subscriptable
# Unexpected error at index 15877: 'float' object is not subscriptable
# Unexpected error at index 15880: 'float' object is not subscriptable
# Unexpected error at index 15881: 'float' object is not subscriptable
# Unexpected error at index 15882: 'float' object is not subscriptable
# Unexpected error at index 15886: 'float' object is not subscriptable
# Unexpected error at index 15890: 'float' object is not subscriptable
# Unexpected error at index 15894: 'float' object is not subscriptable
# Unexpected error at index 15897: 'float' object is not subscriptable
# Unexpected error at index 15900: 'float' object is not subscriptable
# Unexpected error at index 15902: 'float' object is not subscriptable
# Unexpected error at index 15904: 'float' object is not subscriptable
# Unexpected error at index 15908: 'float' object is not subscriptable
# Unexpected error at index 15910: 'float' object is not subscriptable
# Unexpected error at index 15913: 'float' object is not subscriptable
# Unexpected error at index 15914: 'float' object is not subscriptable
# Unexpected error at index 15922: 'float' object is not subscriptable
# Unexpected error at index 15925: 'float' object is not subscriptable
# Unexpected error at index 15926: 'float' object is not subscriptable
# Unexpected error at index 15928: 'float' object is not subscriptable
# Unexpected error at index 15931: 'float' object is not subscriptable
# Unexpected error at index 15932: 'float' object is not subscriptable
# Unexpected error at index 15934: 'float' object is not subscriptable
# Unexpected error at index 15935: 'float' object is not subscriptable
# Unexpected error at index 15936: 'float' object is not subscriptable
# Unexpected error at index 15937: 'float' object is not subscriptable
# Unexpected error at index 15938: 'float' object is not subscriptable
# Unexpected error at index 15941: 'float' object is not subscriptable
# Unexpected error at index 15942: 'float' object is not subscriptable
# Unexpected error at index 15943: 'float' object is not subscriptable
# Unexpected error at index 15946: 'float' object is not subscriptable
# Unexpected error at index 15951: 'float' object is not subscriptable
# Unexpected error at index 15954: 'float' object is not subscriptable
# Unexpected error at index 15960: 'float' object is not subscriptable
# Unexpected error at index 15969: 'float' object is not subscriptable
# Unexpected error at index 15973: 'float' object is not subscriptable
# Unexpected error at index 15980: 'float' object is not subscriptable
# Unexpected error at index 15982: 'float' object is not subscriptable
# Unexpected error at index 15983: 'float' object is not subscriptable
# Unexpected error at index 15985: 'float' object is not subscriptable
# Unexpected error at index 15986: 'float' object is not subscriptable
# Unexpected error at index 15988: 'float' object is not subscriptable
# Unexpected error at index 15989: 'float' object is not subscriptable
# Unexpected error at index 15993: 'float' object is not subscriptable
# Unexpected error at index 15994: 'float' object is not subscriptable
# Unexpected error at index 15995: 'float' object is not subscriptable
# Unexpected error at index 16006: 'float' object is not subscriptable
# Unexpected error at index 16010: 'float' object is not subscriptable
# Unexpected error at index 16011: 'float' object is not subscriptable
# Unexpected error at index 16015: 'float' object is not subscriptable
# Unexpected error at index 16016: 'float' object is not subscriptable
# Unexpected error at index 16018: 'float' object is not subscriptable
# Unexpected error at index 16022: 'float' object is not subscriptable
# Unexpected error at index 16028: 'float' object is not subscriptable
# Unexpected error at index 16036: 'float' object is not subscriptable
# Unexpected error at index 16043: 'float' object is not subscriptable
# Unexpected error at index 16045: 'float' object is not subscriptable
# Unexpected error at index 16047: 'float' object is not subscriptable
# Unexpected error at index 16050: 'float' object is not subscriptable
# Unexpected error at index 16053: 'float' object is not subscriptable
# Unexpected error at index 16054: 'float' object is not subscriptable
# Unexpected error at index 16061: 'float' object is not subscriptable
# Unexpected error at index 16062: 'float' object is not subscriptable
# Unexpected error at index 16064: 'float' object is not subscriptable
# Unexpected error at index 16065: 'float' object is not subscriptable
# Unexpected error at index 16069: 'float' object is not subscriptable
# Unexpected error at index 16070: 'float' object is not subscriptable
# Unexpected error at index 16074: 'float' object is not subscriptable
# Unexpected error at index 16075: 'float' object is not subscriptable
# Unexpected error at index 16076: 'float' object is not subscriptable
# Unexpected error at index 16081: 'float' object is not subscriptable
# Unexpected error at index 16082: 'float' object is not subscriptable
# Unexpected error at index 16090: 'float' object is not subscriptable
# Unexpected error at index 16099: 'float' object is not subscriptable
# Unexpected error at index 16105: 'float' object is not subscriptable
# Unexpected error at index 16107: 'float' object is not subscriptable
# Unexpected error at index 16108: 'float' object is not subscriptable
# Unexpected error at index 16113: 'float' object is not subscriptable
# Unexpected error at index 16116: 'float' object is not subscriptable
# Unexpected error at index 16117: 'float' object is not subscriptable
# Unexpected error at index 16118: 'float' object is not subscriptable
# Unexpected error at index 16119: 'float' object is not subscriptable
# Unexpected error at index 16121: 'float' object is not subscriptable
# Unexpected error at index 16126: 'float' object is not subscriptable
# Unexpected error at index 16127: 'float' object is not subscriptable
# Unexpected error at index 16130: 'float' object is not subscriptable
# Unexpected error at index 16133: 'float' object is not subscriptable
# Unexpected error at index 16137: 'float' object is not subscriptable
# Unexpected error at index 16144: 'float' object is not subscriptable
# Unexpected error at index 16148: 'float' object is not subscriptable
# Unexpected error at index 16151: 'float' object is not subscriptable
# Unexpected error at index 16160: 'float' object is not subscriptable
# Unexpected error at index 16161: 'float' object is not subscriptable
# Unexpected error at index 16165: 'float' object is not subscriptable
# Unexpected error at index 16188: 'float' object is not subscriptable
# Unexpected error at index 16191: 'float' object is not subscriptable
# Unexpected error at index 16199: 'float' object is not subscriptable
# Unexpected error at index 16201: 'float' object is not subscriptable
# Unexpected error at index 16203: 'float' object is not subscriptable
# Unexpected error at index 16205: 'float' object is not subscriptable
# Unexpected error at index 16206: 'float' object is not subscriptable
# Unexpected error at index 16210: 'float' object is not subscriptable
# Unexpected error at index 16211: 'float' object is not subscriptable
# Unexpected error at index 16229: 'float' object is not subscriptable
# Unexpected error at index 16233: 'float' object is not subscriptable
# Unexpected error at index 16239: 'float' object is not subscriptable
# Unexpected error at index 16246: 'float' object is not subscriptable
# Unexpected error at index 16255: 'float' object is not subscriptable
# Unexpected error at index 16259: 'float' object is not subscriptable
# Unexpected error at index 16270: 'float' object is not subscriptable
# Unexpected error at index 16271: 'float' object is not subscriptable
# Unexpected error at index 16275: 'float' object is not subscriptable
# Unexpected error at index 16283: 'float' object is not subscriptable
# Unexpected error at index 16302: 'float' object is not subscriptable
# Unexpected error at index 16305: 'float' object is not subscriptable
# Unexpected error at index 16310: 'float' object is not subscriptable
# Unexpected error at index 16313: 'float' object is not subscriptable
# Unexpected error at index 16315: 'float' object is not subscriptable
# Unexpected error at index 16334: 'float' object is not subscriptable
# Unexpected error at index 16345: 'float' object is not subscriptable
# Unexpected error at index 16352: 'float' object is not subscriptable
# Unexpected error at index 16368: 'float' object is not subscriptable
# Unexpected error at index 16374: 'float' object is not subscriptable
# Unexpected error at index 16377: 'float' object is not subscriptable
# Unexpected error at index 16393: 'float' object is not subscriptable
# Unexpected error at index 16406: 'float' object is not subscriptable
# Unexpected error at index 16414: 'float' object is not subscriptable
# Unexpected error at index 16420: 'float' object is not subscriptable
# Unexpected error at index 16431: 'float' object is not subscriptable
# Unexpected error at index 16433: 'float' object is not subscriptable
# Unexpected error at index 16436: 'float' object is not subscriptable
# Unexpected error at index 16437: 'float' object is not subscriptable
# Unexpected error at index 16438: 'float' object is not subscriptable
# Unexpected error at index 16441: 'float' object is not subscriptable
# Unexpected error at index 16443: 'float' object is not subscriptable
# Unexpected error at index 16444: 'float' object is not subscriptable
# Unexpected error at index 16450: 'float' object is not subscriptable
# Unexpected error at index 16452: 'float' object is not subscriptable
# Unexpected error at index 16457: 'float' object is not subscriptable
# Unexpected error at index 16461: 'float' object is not subscriptable
# Unexpected error at index 16478: 'float' object is not subscriptable
# Unexpected error at index 16489: 'float' object is not subscriptable
# Unexpected error at index 16496: 'float' object is not subscriptable
# Unexpected error at index 16515: 'float' object is not subscriptable
# Unexpected error at index 16536: 'float' object is not subscriptable
# Unexpected error at index 16538: 'float' object is not subscriptable
# Unexpected error at index 16543: 'float' object is not subscriptable
# Unexpected error at index 16556: 'float' object is not subscriptable
# Unexpected error at index 16559: 'float' object is not subscriptable
# Unexpected error at index 16562: 'float' object is not subscriptable
# Unexpected error at index 16575: 'float' object is not subscriptable
# Unexpected error at index 16588: 'float' object is not subscriptable
# Unexpected error at index 16591: 'float' object is not subscriptable
# Unexpected error at index 16592: 'float' object is not subscriptable
# Unexpected error at index 16593: 'float' object is not subscriptable
# Unexpected error at index 16603: 'float' object is not subscriptable
# Unexpected error at index 16604: 'float' object is not subscriptable
# Unexpected error at index 16612: 'float' object is not subscriptable
# Unexpected error at index 16622: 'float' object is not subscriptable
# Unexpected error at index 16624: 'float' object is not subscriptable
# Unexpected error at index 16627: 'float' object is not subscriptable
# Unexpected error at index 16628: 'float' object is not subscriptable
# Unexpected error at index 16635: 'float' object is not subscriptable
# Unexpected error at index 16638: 'float' object is not subscriptable
# Unexpected error at index 16641: 'float' object is not subscriptable
# Unexpected error at index 16642: 'float' object is not subscriptable
# Unexpected error at index 16648: 'float' object is not subscriptable
# Unexpected error at index 16652: 'float' object is not subscriptable
# Unexpected error at index 16653: 'float' object is not subscriptable
# Unexpected error at index 16657: 'float' object is not subscriptable
# Unexpected error at index 16660: 'float' object is not subscriptable
# Unexpected error at index 16664: 'float' object is not subscriptable
# Unexpected error at index 16666: 'float' object is not subscriptable
# Unexpected error at index 16668: 'float' object is not subscriptable
# Unexpected error at index 16673: 'float' object is not subscriptable
# Unexpected error at index 16674: 'float' object is not subscriptable
# Unexpected error at index 16678: 'float' object is not subscriptable
# Unexpected error at index 16679: 'float' object is not subscriptable
# Unexpected error at index 16680: 'float' object is not subscriptable
# Unexpected error at index 16683: 'float' object is not subscriptable
# Unexpected error at index 16684: 'float' object is not subscriptable
# Unexpected error at index 16695: 'float' object is not subscriptable
# Unexpected error at index 16702: 'float' object is not subscriptable
# Unexpected error at index 16705: 'float' object is not subscriptable
# Unexpected error at index 16707: 'float' object is not subscriptable
# Unexpected error at index 16720: 'float' object is not subscriptable
# Unexpected error at index 16724: 'float' object is not subscriptable
# Unexpected error at index 16733: 'float' object is not subscriptable
# Unexpected error at index 16735: 'float' object is not subscriptable
# Unexpected error at index 16736: 'float' object is not subscriptable
# Unexpected error at index 16747: 'float' object is not subscriptable
# Unexpected error at index 16750: 'float' object is not subscriptable
# Unexpected error at index 16753: 'float' object is not subscriptable
# Unexpected error at index 16755: 'float' object is not subscriptable
# Unexpected error at index 16757: 'float' object is not subscriptable
# Unexpected error at index 16758: 'float' object is not subscriptable
# Unexpected error at index 16767: 'float' object is not subscriptable
# Unexpected error at index 16774: 'float' object is not subscriptable
# Unexpected error at index 16777: 'float' object is not subscriptable
# Unexpected error at index 16787: 'float' object is not subscriptable
# Unexpected error at index 16791: 'float' object is not subscriptable
# Unexpected error at index 16794: 'float' object is not subscriptable
# Unexpected error at index 16801: 'float' object is not subscriptable
# Unexpected error at index 16803: 'float' object is not subscriptable
# Unexpected error at index 16807: 'float' object is not subscriptable
# Unexpected error at index 16813: 'float' object is not subscriptable
# Unexpected error at index 16815: 'float' object is not subscriptable
# Unexpected error at index 16819: 'float' object is not subscriptable
# Unexpected error at index 16821: 'float' object is not subscriptable
# Unexpected error at index 16824: 'float' object is not subscriptable
# Unexpected error at index 16827: 'float' object is not subscriptable
# Unexpected error at index 16832: 'float' object is not subscriptable
# Unexpected error at index 16835: 'float' object is not subscriptable
# Unexpected error at index 16837: 'float' object is not subscriptable
# Unexpected error at index 16849: 'float' object is not subscriptable
# Unexpected error at index 16855: 'float' object is not subscriptable
# Unexpected error at index 16856: 'float' object is not subscriptable
# Unexpected error at index 16861: 'float' object is not subscriptable
# Unexpected error at index 16865: 'float' object is not subscriptable
# Unexpected error at index 16867: 'float' object is not subscriptable
# Unexpected error at index 16880: 'float' object is not subscriptable
# Unexpected error at index 16888: 'float' object is not subscriptable
# Unexpected error at index 16893: 'float' object is not subscriptable
# Unexpected error at index 16902: 'float' object is not subscriptable
# Unexpected error at index 16903: 'float' object is not subscriptable
# Unexpected error at index 16930: 'float' object is not subscriptable
# Unexpected error at index 16934: 'float' object is not subscriptable
# Unexpected error at index 16944: 'float' object is not subscriptable
# Unexpected error at index 16948: 'float' object is not subscriptable
# Unexpected error at index 16952: 'float' object is not subscriptable
# Unexpected error at index 16953: 'float' object is not subscriptable
# Unexpected error at index 16957: 'float' object is not subscriptable
# Unexpected error at index 16959: 'float' object is not subscriptable
# Unexpected error at index 16968: 'float' object is not subscriptable
# Unexpected error at index 16969: 'float' object is not subscriptable
# Unexpected error at index 16975: 'float' object is not subscriptable
# Unexpected error at index 16980: 'float' object is not subscriptable
# Unexpected error at index 16987: 'float' object is not subscriptable
# Unexpected error at index 16989: 'float' object is not subscriptable
# Unexpected error at index 16991: 'float' object is not subscriptable
# Unexpected error at index 17000: 'float' object is not subscriptable
# Unexpected error at index 17003: 'float' object is not subscriptable
# Unexpected error at index 17004: 'float' object is not subscriptable
# Unexpected error at index 17006: 'float' object is not subscriptable
# Unexpected error at index 17008: 'float' object is not subscriptable
# Unexpected error at index 17009: 'float' object is not subscriptable
# Unexpected error at index 17015: 'float' object is not subscriptable
# Unexpected error at index 17028: 'float' object is not subscriptable

# %%
selected_df['year_released'] = year_released

# %%
movie_stg0 = imdb_df.merge(selected_df,
                           left_on=['primaryTitle', 'startYear'],
                           right_on=['title', 'year_released'])

# %%
movie_stg0.shape
# Out:
# (9371, 34)

# %%
movie_stg1 = movie_stg0.drop(['Unnamed: 0', 'titleType', 'id', 'titleId', 'tagline', 'poster_path', 'backdrop_path', 'recommendations'], axis=1)

# %%
movie_stg1.isna().sum()
# Out:
# primaryTitle               0
# originalTitle              0
# startYear                  0
# Genre                      0
# directors                 17
# writers                  247
# averageRating              0
# numVotes                   0
# title                      0
# genres                    59
# original_language          0
# overview                  96
# popularity                 0
# production_companies     533
# release_date               0
# budget                     0
# revenue                    0
# runtime                   14
# status                     0
# vote_average               0
# vote_count                 0
# credits                   50
# keywords                1465
# trailer_views              0
# trailer_likes              0
# year_released              0
# dtype: int64

# %%
movie_stg1.shape
# Out:
# (9371, 26)

# %% [markdown]
# #### Checking for redundent movie

# %%
len(movie_stg1[['primaryTitle', 'startYear']].drop_duplicates())
# Out:
# 8854

# %%
redundant_dict = {}

for i in range(movie_stg1.shape[0]):
    movie_name = movie_stg1.iloc[i, 0]  # Use square brackets for iloc
    year = movie_stg1.iloc[i, 2]
    if (movie_name, year) not in redundant_dict:
        redundant_dict[(movie_name, year)] = (1, [i])  # Initialize with 1 occurrence and the index
    else:
        count, indices = redundant_dict[(movie_name, year)]  # Unpack the tuple
        redundant_dict[(movie_name, year)] = (count + 1, indices + [i])  # Update the count and append index

# %%
filtered_list = [(key, index) for key, (count, index) in redundant_dict.items() if count > 1]
for i in filtered_list:
    print(i)
# Out:
# (('The Big Swap', '1998'), [54, 55])
# (('Reine & Mimmi i fjällen!', '1997'), [212, 213])
# (('Soldier', '1998'), [230, 881])
# (('An Ideal Husband', '1999'), [396, 601])
# (('Life', '1999'), [404, 405])
# (('Money No Enough', '1998'), [422, 423])
# (('The Ride', '1997'), [432, 1321])
# (('Ride with the Devil', '1999'), [468, 1007])
# (('Men Cry Bullets', '1998'), [559, 560])
# (('Last Night', '1998'), [581, 1313])
# (('The Beach', '2000'), [628, 1591])
# (('Limbo', '1999'), [633, 8274])
# (('Gossip', '2000'), [714, 988])
# (('Between Your Legs', '1999'), [717, 2609])
# (('Australian Made: The Movie', '1987'), [816, 817])
# (('O Astrapogiannos', '1970'), [824, 825, 826])
# (('Monsieur Zivaco', '1967'), [838, 839])
# (('Dil Kya Kare', '1999'), [906, 907])
# (('Secret Society', '2000'), [912, 913])
# (('Shool', '1999'), [932, 933])
# (('Devdas', '2002'), [993, 1561])
# (('Jungle', '2000'), [1083, 1084])
# (('Connect 5', '1996'), [1093, 1094])
# (('Jackpot', '2001'), [1143, 1144])
# (('Todo menos la chica', '2002'), [1146, 1147])
# (('Sexy Comedy', '2001'), [1160, 1161])
# (('Narasimham', '2000'), [1235, 1236])
# (('Millennium Stars', '2000'), [1301, 1302])
# (('Love Ke Liye Kuch Bhi Karega', '2001'), [1335, 1336])
# (('Desire', '2002'), [1344, 1649])
# (('Heidi', '2005'), [1413, 2490])
# (('Dead End', '2003'), [1469, 1983])
# (('The In-Laws', '2003'), [1510, 1796])
# (('Heer Ranjha', '1970'), [1541, 1542])
# (('Three', '2002'), [1578, 1703])
# (('Stereoblood', '2002'), [1597, 1598, 1599])
# (('The Missing', '2003'), [1681, 2047])
# (('Hostage', '2005'), [1709, 2732])
# (('Summer Storm', '2004'), [1748, 2339])
# (('Dark Woods', '2003'), [1779, 1791])
# (('Promised Land', '2004'), [1917, 2375])
# (('Gray Matters', '2006'), [1960, 4460])
# (('November', '2003'), [1970, 2070])
# (('Words of My Perfect Teacher', '2003'), [2079, 2080])
# (('My Big Phat Hip Hop Family', '2005'), [2090, 2091])
# (('El chocolate del loro', '2004'), [2174, 2175])
# (('Chaos', '2005'), [2200, 2224])
# (('The Guardian', '2006'), [2231, 2698])
# (('Countdown', '2004'), [2295, 6343])
# (('A Year Without Love', '2005'), [2321, 2322])
# (('Red Eye', '2005'), [2352, 2353])
# (('Noise', '2007'), [2389, 3103])
# (('Hell', '2005'), [2420, 2748])
# (('Before We Go', '2014'), [2513, 7596])
# (("Emmanuel's Gift", '2005'), [2550, 2551])
# (('Hot Milk', '2005'), [2661, 2662])
# (('Aithe', '2003'), [2674, 2675])
# (('15', '2005'), [2691, 2692])
# (('Naran', '2005'), [2712, 2713])
# (('Simple Things', '2007'), [2851, 2852, 3193, 3194])
# (('Good Boy, Bad Boy', '2007'), [2908, 2909])
# (('The Bridge', '2006'), [3061, 3308])
# (('Maximum Ride', '2016'), [3148, 3149])
# (('Pandemic', '2009'), [3151, 4141])
# (('Me & You, Us, Forever', '2008'), [3155, 3156])
# (('Classmates', '2006'), [3237, 3238])
# (('The Mist', '2007'), [3267, 3427])
# (('The Class', '2007'), [3334, 3425])
# (("The Devil's Flower", '2010'), [3339, 3340])
# (('The Matriarch', '2007'), [3345, 3346])
# (('Old Dogs', '2009'), [3402, 3950])
# (('Ghost Town', '2008'), [3437, 5247])
# (('The Sholay Girl', '2019'), [3448, 3449])
# (('Block Z', '2020'), [3459, 3460])
# (('Kingdom Men Rising', '2019'), [3476, 3477])
# (('Chhalawa', '2019'), [3478, 3479])
# (('Odessa', '2019'), [3485, 3486, 3487])
# (('Alice in Wonderland', '2010'), [3489, 5969])
# (('Chain Kulii Ki Main Kulii', '2007'), [3497, 3498])
# (('Land', '2021'), [3534, 5069])
# (('Love Again', '2023'), [3539, 6836])
# (('Censored', '2019'), [3571, 3572])
# (('Trouble', '2019'), [3606, 8643])
# (('The Green Cat', '2019'), [3607, 3608])
# (('The Bounty Hunter', '2010'), [3612, 4943])
# (('Araf 3: Cinler Kitabi', '2019'), [3615, 3616])
# (('Miracle in Cell No. 7', '2019'), [3626, 3780])
# (('Baaji', '2019'), [3634, 3635])
# (('Republic Z', '2018'), [3648, 9365])
# (('The Call', '2020'), [3672, 4491])
# (('The Cabin House', '2019'), [3687, 3688])
# (('My Mom is a Character 3', '2019'), [3698, 3699])
# (('Babylon', '2022'), [3708, 4933])
# (('Seer Movie 7: Crazy Intelligence', '2019'), [3715, 3716])
# (('Wolf', '2021'), [3735, 4639])
# (('Nothing But the Truth', '2008'), [3746, 5347])
# (('Quarantine', '2008'), [3775, 8937])
# (('Rescue Me: A Home 4 Spot', '2019'), [3802, 3803])
# (('Love Mocktail', '2020'), [3804, 3805, 3806])
# (('Border', '2018'), [3838, 8105])
# (('Puaada', '2021'), [3843, 3844, 3845])
# (('The Boonies', '2021'), [3857, 3858])
# (('Heaven', '2020'), [3883, 3884])
# (('Hillary: Ocean to Sky', '2019'), [3901, 3902])
# (('True to the Game 2', '2020'), [3911, 3912, 3913])
# (('My Heart Goes Boom!', '2020'), [3914, 3915, 3916])
# (('Dog', '2022'), [3923, 5906])
# (('Big Eyes', '2014'), [3929, 7537])
# (('Burlesque', '2010'), [3930, 5177])
# (('Beast', '2022'), [3951, 4560])
# (('Rainy in Glenageary', '2019'), [3976, 3977])
# (('James', '2022'), [3990, 3991])
# (('Stolen', '2009'), [3996, 4880])
# (('Forgotten', '2017'), [4064, 8754])
# (('The Invitation', '2022'), [4081, 4464])
# (('Adam', '2009'), [4143, 4877])
# (('Soulmate', '2023'), [4185, 4523, 4730])
# (('Charlie', '2015'), [4187, 7903])
# (('The Miracle', '2009'), [4195, 4196])
# (('Happy Days', '2007'), [4245, 4246])
# (('Leap Year', '2010'), [4251, 5082])
# (("DeMarcus Cousins Presents Boogie's Comedy Slam", '2020'), [4285, 4286])
# (('Run', '2020'), [4334, 9136])
# (('High School', '2010'), [4358, 4937])
# (('Madambi', '2008'), [4390, 4391])
# (('One Life at a Time', '2020'), [4393, 4394, 4395])
# (('Hercules', '2014'), [4400, 7388])
# (('The Tempest', '2010'), [4425, 5423])
# (('Josh', '2009'), [4490, 5010])
# (('Nochebuena', '2008'), [4548, 4549])
# (('Frozen', '2010'), [4561, 5241])
# (('Russian Spleen', '2019'), [4564, 4565, 4566])
# (('Rodney', '2009'), [4580, 4581])
# (('Motherland', '2009'), [4582, 4586, 4834])
# (('Vote Jesus: The Chronicles of Ken Stevenson', '2009'), [4606, 4607])
# (('I Am Divine', '2013'), [4650, 4651])
# (('Upside Down', '2012'), [4685, 6044])
# (('Love and Monsters', '2020'), [4703, 6169])
# (('Limbo', '2021'), [4760, 4761])
# (('Anna', '2019'), [4809, 8848])
# (('The Way', '2010'), [4873, 5444])
# (('Big Sur', '2013'), [4917, 4918])
# (('Together', '2021'), [4924, 4925, 5056, 5057])
# (('What If', '2013'), [4979, 6383])
# (('The Visit', '2015'), [5020, 7164, 7325])
# (('Super', '2010'), [5022, 5649])
# (('Gold', '2022'), [5068, 8338])
# (('Smile', '2022'), [5104, 5154, 6135, 6267])
# (('A Better Life', '2011'), [5110, 5953])
# (('Boy', '2010'), [5116, 6786])
# (('Seeking Nirvana', '2012'), [5129, 5130])
# (('Dhamaka', '2022'), [5139, 6149])
# (('Chattambinadu', '2009'), [5152, 5153])
# (('The Edge', '2010'), [5166, 5468])
# (('The Killing of Jacob Marr', '2010'), [5192, 5193])
# (('Abduction', '2011'), [5214, 6491])
# (('La venganza de Ira Vamp', '2010'), [5279, 5280])
# (('Underdogs', '2013'), [5292, 6066])
# (('Air', '2023'), [5314, 6636])
# (('The Artist', '2011'), [5352, 5690])
# (('Evil Intent', '2010'), [5354, 5355])
# (('The Roommates Party', '2015'), [5368, 5369])
# (('Cinderella', '2015'), [5371, 7907])
# (('The Beatles: Get Back - The Rooftop Concert', '2022'), [5437, 5438])
# (('The Hunter', '2011'), [5463, 5816])
# (('Every Thing Will Be Fine', '2015'), [5472, 7525])
# (('Malarvaadi Arts Club', '2010'), [5476, 5477])
# (('Weekend', '2011'), [5494, 5629, 5806])
# (('Aagathan', '2010'), [5501, 5502])
# (('The Legend of Silk Boy', '2010'), [5505, 5506])
# (('Blood Ties', '2013'), [5552, 6795])
# (('Michael', '2011'), [5566, 5802])
# (('The Little Prince', '2015'), [5569, 8032])
# (('InAPPropriate Comedy', '2013'), [5570, 5571])
# (('Jackie', '2010'), [5575, 5576])
# (('The Cursed', '2021'), [5584, 9370])
# (('Wilson', '2017'), [5607, 8804])
# (('Traffic', '2011'), [5681, 5682])
# (('Life of the Party', '2018'), [5693, 8157])
# (('Make Your Move', '2013'), [5695, 5696])
# (('War of the Buttons', '2011'), [5712, 5713, 5757, 5758])
# (('Gone', '2012'), [5717, 6181])
# (('Happy Birthday', '2022'), [5734, 6058])
# (('The Darkness', '2016'), [5778, 7831])
# (('Spotlight', '2015'), [5796, 8942])
# (('Phantom', '2013'), [5817, 6884])
# (('One Small Hitch', '2013'), [5839, 5840])
# (('Begin Again', '2013'), [5844, 5890])
# (('Aftersun', '2022'), [5856, 5883])
# (('The Man Inside', '2012'), [5909, 6682])
# (('Haunted', '2013'), [5912, 6081])
# (('The Great Wall', '2016'), [5959, 8867])
# (('The Precocious and Brief Life of Sabina Rivas', '2012'), [5982, 5983])
# (('Rocketman', '2019'), [5989, 9094])
# (('My Way', '2012'), [5993, 6229, 6497])
# (('Sultanat', '2014'), [6006, 6007])
# (('The Hunt', '2012'), [6047, 6628])
# (('Fachon Models', '2014'), [6084, 6085])
# (('Mouna Guru', '2011'), [6094, 6095])
# (('Welcome Home', '2014'), [6098, 6099])
# (('The Walk', '2015'), [6102, 7113])
# (('Turning Tide', '2013'), [6103, 6104])
# (('Thuppakki', '2012'), [6139, 6140])
# (('The Infected', '2011'), [6141, 6142])
# (('Macho Man', '2015'), [6159, 6160])
# (('White Night', '2012'), [6168, 6692])
# (('Home', '2015'), [6172, 8277])
# (('The Mountain Between Us', '2017'), [6175, 6176])
# (('Trouble Is My Business', '2018'), [6202, 6203])
# (('Rush', '2012'), [6213, 6214])
# (('True Story', '2015'), [6236, 6900])
# (('On My Way', '2013'), [6252, 6253])
# (('Holy Ghost People', '2013'), [6268, 6269])
# (('Absolution', '2015'), [6270, 7088, 7123])
# (('Homefront', '2013'), [6289, 6574])
# (('Secrets of War', '2014'), [6368, 6369])
# (('Camp', '2013'), [6370, 6371])
# (('I Hugged the Berlin Patient', '2013'), [6386, 6387])
# (('Man Up', '2015'), [6390, 6871])
# (('Coco', '2017'), [6395, 8731])
# (('Zinda Bhaag', '2013'), [6413, 6414])
# (('A Quiet Passion', '2016'), [6422, 6423])
# (('Rage', '2014'), [6438, 6439])
# (('The Family', '2013'), [6455, 7456])
# (('Ek Thi Daayan', '2013'), [6465, 6466])
# (('Husbands in Goa', '2012'), [6467, 6468])
# (('The Principle', '2014'), [6501, 6502])
# (('The Green Marker Scare', '2012'), [6537, 6538])
# (('Arrambam', '2013'), [6569, 6570])
# (('Mobster', '2013'), [6582, 6583])
# (('Boss', '2013'), [6584, 7213])
# (('Mt. Zion', '2013'), [6588, 6589])
# (('Da Thadiya', '2012'), [6607, 6608])
# (('Kicking Off', '2013'), [6629, 6630])
# (('Balupu', '2013'), [6638, 6639])
# (('Split', '2016'), [6641, 7019, 7179, 7848, 8381])
# (('Natholi Oru Cheriya Meenalla', '2013'), [6654, 6655])
# (('Final: The Rapture', '2013'), [6667, 6668])
# (('Celluloid', '2013'), [6672, 6673])
# (('El Almany', '2012'), [6684, 6685])
# (('Tomorrow', '2015'), [6729, 7595])
# (('Sound Thoma', '2013'), [6744, 6745])
# (('Ethir Neechal', '2013'), [6760, 6761])
# (('Ugly', '2013'), [6763, 6764])
# (('The Circle', '2017'), [6797, 7520])
# (('The Guest', '2014'), [6824, 7015])
# (('Coming Home', '2014'), [6842, 6903])
# (('Club Life', '2015'), [6856, 6857])
# (('Almost Holy', '2015'), [6880, 6881])
# (('Dealt', '2017'), [6905, 6906, 6907])
# (('For Love or Money', '2014'), [6910, 6911, 7535, 7536])
# (('Jimmy Vestvood: Amerikan Hero', '2016'), [6915, 6916])
# (('Soulless 2', '2015'), [6917, 6918])
# (('The Nightmare', '2015'), [6919, 7022])
# (('Extinction', '2018'), [6957, 9042])
# (('The Cosplayers', '2013'), [6969, 6970])
# (('Requiem for the American Dream', '2015'), [6993, 6994])
# (('Heist', '2015'), [6996, 7920])
# (('Last Days in Vietnam', '2014'), [6998, 6999])
# (('Extraction', '2015'), [7012, 7556])
# (('The Forest', '2016'), [7050, 7857])
# (('O21', '2014'), [7055, 7056])
# (('Oka Laila Kosam', '2014'), [7062, 7063])
# (('Jalaibee', '2015'), [7094, 7095])
# (('Thegidi', '2014'), [7160, 7161])
# (('The Witness', '2015'), [7165, 7166, 7853, 7854])
# (('Blue Jay', '2016'), [7171, 8290])
# (('People Get Eaten', '2015'), [7202, 7203])
# (('Happy Journey', '2014'), [7225, 7594])
# (('Body', '2015'), [7257, 7549])
# (('February 30th', '2012'), [7269, 7270])
# (('Truman', '2015'), [7272, 7273])
# (('Love', '2015'), [7287, 7759])
# (('Angels', '2014'), [7295, 7296])
# (('Terminal', '2018'), [7311, 7600])
# (('Cargo', '2017'), [7340, 7983, 8102])
# (('Stronger', '2017'), [7348, 8219])
# (('The 312', '2017'), [7358, 7359])
# (('The Neighbor', '2017'), [7360, 8717])
# (('Star', '2014'), [7369, 7370])
# (('Power', '2014'), [7371, 7372, 9214, 9215])
# (('My Old Classmate', '2014'), [7375, 7376])
# (('Café. Waiting. Love', '2014'), [7384, 7385])
# (("I Don't Believe in Anarchy", '2014'), [7425, 7426])
# (('Other People', '2016'), [7457, 7458])
# (('Toro', '2016'), [7481, 7482, 8361, 8362])
# (('Frau Müller muss weg!', '2015'), [7483, 7484])
# (('Victoria', '2015'), [7488, 7660])
# (('Hero', '2015'), [7489, 7490, 7604, 7605])
# (('The Void', '2016'), [7498, 8462])
# (('Yennai Arindhaal', '2015'), [7500, 7501])
# (('Terrace House: Closing Door', '2015'), [7507, 7508])
# (('Viejos amigos', '2014'), [7521, 7522])
# (('Kayal', '2014'), [7523, 7524])
# (('Theresa & Allison', '2019'), [7526, 7527, 7528])
# (('Game Therapy', '2015'), [7569, 7570])
# (('7 Witches', '2017'), [7571, 7572])
# (('Papanasam', '2015'), [7582, 7583])
# (('RangiTaranga', '2015'), [7586, 7587, 7588])
# (('Temper', '2015'), [7592, 7593])
# (('Flora', '2017'), [7597, 7598])
# (('Monsoon', '2015'), [7612, 8035])
# (('Tex Montana Will Survive!', '2015'), [7632, 7633])
# (('Kidnapping, Caucasian Style', '2014'), [7639, 7640, 7641])
# (('Paradise', '2016'), [7647, 8662])
# (('Disney Junior Party', '2015'), [7663, 7664])
# (('Karachi Se Lahore', '2015'), [7667, 7668])
# (('Rana Vikrama', '2015'), [7671, 7672])
# (("Don't Forget About Me", '2016'), [7677, 7678])
# (('Denial', '2016'), [7692, 8287])
# (('Kevin Hart: What Now?', '2016'), [7699, 7700])
# (('The Seagull', '2018'), [7709, 9130])
# (('Jawani Phir Nahi Ani', '2015'), [7719, 7720])
# (('The Fury of a Patient Man', '2016'), [7753, 7754])
# (('The Promise', '2016'), [7757, 8351])
# (('Maya', '2015'), [7762, 7881])
# (('Indru Netru Naalai', '2015'), [7771, 7772])
# (('Angrej', '2015'), [7789, 7790])
# (('Loham', '2015'), [7797, 7798])
# (('Hotel Infierno', '2015'), [7800, 7801])
# (('Killing Veerappan', '2016'), [7806, 7807])
# (('Perfect Strangers', '2016'), [7811, 8476])
# (('Forever Young', '2016'), [7812, 7813])
# (('Dobara Phir Se', '2016'), [7870, 7871])
# (('The Transfiguration', '2016'), [7882, 7883])
# (("Where You're Meant to Be", '2016'), [7892, 7893])
# (('True to the Game', '2017'), [7924, 7925])
# (('Savage', '2017'), [7931, 7932, 8903, 8904])
# (('The Wild Soccer Bunch 6', '2016'), [7936, 7937])
# (('Zoology', '2016'), [7941, 7942])
# (('Rabidity', '2016'), [7945, 7946])
# (('Auto Shop of Horrors', '2016'), [7947, 7948])
# (('Shortwave', '2016'), [7952, 7953])
# (('Escape Room', '2017'), [7958, 8223])
# (('Talent Has Hunger', '2016'), [7970, 7971])
# (('Dhaad', '2018'), [7974, 7975])
# (('Abracadabra', '2017'), [7977, 7978])
# (('Maalik', '2016'), [8008, 8009])
# (('The Duelist', '2016'), [8014, 8015])
# (('Actor in Law', '2016'), [8039, 8040])
# (("Jacob's Kingdom of Heaven", '2016'), [8052, 8053])
# (('Brahmotsavam', '2016'), [8073, 8074])
# (('Sarrainodu', '2016'), [8075, 8076])
# (('Shivalinga', '2016'), [8084, 8085])
# (('Pink', '2016'), [8110, 8126])
# (('My Entire High School Sinking Into the Sea', '2016'), [8112, 8113])
# (('Oppam', '2016'), [8117, 8118])
# (('Kaptaan', '2016'), [8136, 8137])
# (('Punjab Nahi Jaungi', '2017'), [8138, 8139])
# (('If I Were a Boy', '2017'), [8141, 8142])
# (('Ovunque tu sarai', '2017'), [8146, 8147, 8148])
# (('An Almost Perfect Country', '2016'), [8152, 8153])
# (('Black Snow', '2017'), [8154, 8155])
# (('Beautifully Broken', '2018'), [8167, 8168, 8169])
# (('Madaari', '2016'), [8197, 8198])
# (('Byomkesh Bakshi', '2015'), [8217, 8218])
# (('Insomnia Lover', '2016'), [8229, 8230])
# (('Tiyaan', '2017'), [8233, 8234])
# (('Let There Be Light', '2017'), [8240, 8401])
# (('Pelli Choopulu', '2016'), [8252, 8253])
# (('A Trip to the Moon', '2017'), [8266, 8267])
# (('Ezra', '2017'), [8281, 8282, 8283])
# (('Janatha Garage', '2016'), [8303, 8304])
# (('Babu Bangaram', '2016'), [8307, 8308])
# (('Better Days', '2019'), [8320, 9308])
# (('The Great Father', '2017'), [8329, 8330])
# (('Shed Skin Papa', '2016'), [8374, 8375, 8376])
# (('Zoo', '2018'), [8383, 8895])
# (('Sakhavu', '2017'), [8392, 8393, 8394])
# (('Served Like a Girl', '2017'), [8397, 8398])
# (('Father and Son', '2017'), [8403, 8568])
# (('Ava', '2017'), [8408, 8739, 8799])
# (('Mountain', '2017'), [8414, 8415])
# (('Azar', '2017'), [8419, 8420])
# (('Take Off', '2017'), [8425, 8479])
# (('21 Days Later', '2017'), [8428, 8429])
# (('Salute', '2016'), [8445, 8446])
# (('Role Models', '2017'), [8449, 8450])
# (('Sarvann', '2017'), [8452, 8453])
# (('Hey Jude', '2018'), [8500, 8501])
# (('The Pathological Optimist', '2017'), [8503, 8504])
# (('Malapata', '2017'), [8506, 8507])
# (('Shatamanam Bhavati', '2017'), [8513, 8514, 8515])
# (('I Am Nezha', '2016'), [8534, 8535])
# (('To Crack Bloggers', '2016'), [8541, 8542])
# (('The Blackout', '2019'), [8543, 9144, 9169])
# (('McQueen', '2018'), [8561, 8562])
# (('C/O Saira Banu', '2017'), [8570, 8571, 8572])
# (('Selfie', '2017'), [8588, 8589, 8590, 8591, 8592])
# (('Otzi and the Mystery of Time', '2018'), [8597, 8598, 8599])
# (('Sunday Holiday', '2017'), [8601, 8602])
# (('Street Lights', '2018'), [8609, 8610])
# (('Night Shift', '2018'), [8612, 8613])
# (('Rhino Horn', '2018'), [8619, 8620])
# (('Manje Bistre', '2017'), [8621, 8622])
# (('Babumoshai Bandookbaaz', '2017'), [8624, 8625])
# (('Born a King', '2019'), [8627, 8628])
# (('Captain', '2018'), [8635, 8636])
# (('Foxtrot', '2017'), [8640, 8695])
# (('Truth or Dare', '2018'), [8644, 8687])
# (('Queen', '2018'), [8646, 8647])
# (('Summerland', '2020'), [8670, 9120])
# (('Battle', '2018'), [8674, 8675])
# (('Shadow', '2018'), [8683, 8684])
# (('Eye for an Eye', '2019'), [8716, 8983])
# (('Crimea', '2017'), [8726, 8727])
# (('Dharmayuddhaya', '2017'), [8749, 8750])
# (('Misfit', '2017'), [8769, 8770])
# (('Fidaa', '2017'), [8784, 8785])
# (('Pari', '2018'), [8816, 8817, 8987, 8988])
# (('Dog Days', '2018'), [8827, 8828, 9247, 9248])
# (('Shikkari Shambhu', '2018'), [8830, 8831])
# (('Panchavarnathatha', '2018'), [8846, 8847])
# (('Eeda', '2018'), [8855, 8856])
# (('Beats', '2019'), [8860, 9122])
# (('Kuttanadan Marpappa', '2018'), [8879, 8880])
# (('Ira', '2018'), [8885, 8886])
# (('Trip Ubusan: The Lolas vs Zombies', '2017'), [8905, 8906, 8907])
# (('Short Circuit', '2019'), [8908, 8909])
# (('Soorma', '2018'), [8915, 8916])
# (('The Falcons', '2018'), [8918, 8919, 8920])
# (('Cake', '2018'), [8924, 8925])
# (('Jawani Phir Nahi Ani 2', '2018'), [8950, 8951])
# (('The World Before Your Feet', '2018'), [8956, 8957])
# (('They Shall Not Grow Old', '2018'), [8970, 9174])
# (('The Russian Five', '2018'), [8999, 9000])
# (('Praana', '2019'), [9002, 9003, 9004])
# (('Parwaaz Hai Junoon', '2018'), [9008, 9009, 9010])
# (('Taxiwala', '2018'), [9015, 9016])
# (('Monster', '2019'), [9019, 9210, 9314])
# (('Nice to Meet You', '2018'), [9060, 9061, 9062])
# (('Menocchio the Heretic', '2018'), [9071, 9072, 9073])
# (('Chhakka Panja 3', '2018'), [9101, 9102])
# (('Ava', '2020'), [9147, 9159])
# (('Unsubscribe', '2020'), [9166, 9167])
# (('Live Twice, Love Once', '2019'), [9204, 9205])
# (('Girl with No Mouth', '2019'), [9212, 9213])
# (('The Way of the World', '2018'), [9223, 9224])
# (('Moondance', '2020'), [9225, 9226])
# (('The Goya Murders', '2019'), [9234, 9235, 9236])
# (('Laal Kabootar', '2019'), [9277, 9278, 9279])
# (('Twiceland', '2018'), [9282, 9283])
# (('Madhaveeyam', '2019'), [9284, 9285])
# (('3 Bahadur: Rise of the Warriors', '2018'), [9297, 9298])
# (('Ardaas Karaan', '2019'), [9303, 9304])
# (('Hidden Treasures in the Mountain', '2018'), [9319, 9320])
# (('Para toda la muerte', '2020'), [9353, 9354, 9355])

# %%
print(movie_stg1.iloc[212])
# Out:
# primaryTitle                                     Reine & Mimmi i fjällen!
# originalTitle                                    Reine & Mimmi i fjällen!
# startYear                                                            1997
# Genre                                                              Comedy
# directors                                                Magnus Skogsberg
# writers                 Hans Rosenfeldt,Peter Emanuel Falck,Christian ...
# averageRating                                                         2.6
# numVotes                                                            901.0
# title                                            Reine & Mimmi i fjällen!
# genres                                                             Comedy
# original_language                                                      sv
# overview                Mimmi starts to get enough Reine just work all...
# popularity                                                          1.761
# production_companies                          TV4-SF Studios-TV Spartacus
# release_date                                                   1997-08-15
# budget                                                                0.0
# revenue                                                         1224778.0
# runtime                                                              98.0
# status                                                           Released
# vote_average                                                          1.9
# vote_count                                                           10.0
# credits                 Bertram Heribertson-Ing-Marie Carlsson-Sanna E...
# keywords                                                              NaN
# trailer_views                                               325346.266774
# trailer_likes                                               287034.077216
# year_released                                                        1997
# Name: 212, dtype: object

# %%
print(movie_stg1.iloc[213])
# Out:
# primaryTitle                                     Reine & Mimmi i fjällen!
# originalTitle                                    Reine & Mimmi i fjällen!
# startYear                                                            1997
# Genre                                                              Comedy
# directors                                                Magnus Skogsberg
# writers                 Hans Rosenfeldt,Peter Emanuel Falck,Christian ...
# averageRating                                                         2.6
# numVotes                                                            901.0
# title                                            Reine & Mimmi i fjällen!
# genres                                                             Comedy
# original_language                                                      sv
# overview                Mimmi starts to get enough Reine just work all...
# popularity                                                          1.057
# production_companies                          TV4-SF Studios-TV Spartacus
# release_date                                                   1997-08-15
# budget                                                                0.0
# revenue                                                         1224778.0
# runtime                                                              98.0
# status                                                           Released
# vote_average                                                          1.9
# vote_count                                                           10.0
# credits                 Bertram Heribertson-Ing-Marie Carlsson-Sanna E...
# keywords                                                              NaN
# trailer_views                                                80100.763079
# trailer_likes                                               445752.970612
# year_released                                                        1997
# Name: 213, dtype: object

# %%
movie_stg2 = movie_stg1.drop_duplicates(['primaryTitle', 'startYear'])

# %%
movie_stg2.shape
# Out:
# (8854, 26)

# %%
movie_stg2.to_csv('data/balanced.csv')
